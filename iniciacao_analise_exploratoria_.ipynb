# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiaholsback/Aprendizado/blob/main/iniciacao_analise_exploratoria_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aula 1** Com base nos dados do PNAD IBGE

# %% [markdown]
# *Uso de Pandas e Numpy*

# %%
import pandas as pd  # biblioteca com ferramentas para análise de dados/dataframes (pd é um 'apelido')
import numpy as np  # biblioteca com operações matemáticas

# %%
# Pesquisa Nacional por Amostra de Domicílios - PNAD (IGBE)
df = pd.read_csv("https://raw.githubusercontent.com/dayanebravo/AED/main/pes_2012.csv")  # ler dados no formato CSV

# %%
df.head()  #  exibe as primeiras linhas da tabela
# Out:
#    V0101        UF      V0302  V8005   V0404            V4803 V4718 V4720  \
# 0   2012  Rondônia  Masculino     48  Branca  15 anos ou mais  3000  3000
# 1   2012  Rondônia   Feminino     48  Branca  15 anos ou mais  3000  3000
# 2   2012  Rondônia   Feminino     23  Branca  15 anos ou mais  1100  1100
# 3   2012  Rondônia   Feminino     21  Branca          14 anos  1100  1100
# 4   2012  Rondônia   Feminino     54  Branca  15 anos ou mais   NaN   460
#
#    V4729
# 0    232
# 1    232
# 2    232
# 3    232
# 4    232

# %%
df.shape  # informa a dimensão da tabela (linhas, colunas)
# Out:
# (362451, 9)

# %%
df.info()  # informações gerais dos dados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362451 entries, 0 to 362450
# Data columns (total 9 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   V0101   362451 non-null  int64
#  1   UF      362451 non-null  object
#  2   V0302   362451 non-null  object
#  3   V8005   362451 non-null  int64
#  4   V0404   362451 non-null  object
#  5   V4803   362451 non-null  object
#  6   V4718   173539 non-null  object
#  7   V4720   309512 non-null  object
#  8   V4729   362451 non-null  int64
# dtypes: int64(3), object(6)
# memory usage: 24.9+ MB

# %%
df.dtypes  # informa os tipos de dados de cada coluna
# Out:
# V0101     int64
# UF       object
# V0302    object
# V8005     int64
# V0404    object
# V4803    object
# V4718    object
# V4720    object
# V4729     int64
# dtype: object

# %%
df.V4718  #  acessar dados da coluna (precisa tratar esses dados)
# Out:
# 0          3000
# 1          3000
# 2          1100
# 3          1100
# 4           NaN
#           ...
# 362446      NaN
# 362447    20000
# 362448      NaN
# 362449      NaN
# 362450    13000
# Name: V4718, Length: 362451, dtype: object

# %%
df["V4718"]  #  acessar e ALTERAR dados da coluna
# Out:
# 0          3000
# 1          3000
# 2          1100
# 3          1100
# 4           NaN
#           ...
# 362446      NaN
# 362447    20000
# 362448      NaN
# 362449      NaN
# 362450    13000
# Name: V4718, Length: 362451, dtype: object

# %%
df.dropna(axis="columns")  # remove colunas com ao menos um valor inválido, retirou a coluna v4718 (remover coluna não é interessante por perder dados)
# Out:
#         V0101                UF      V0302  V8005   V0404            V4803  \
# 0        2012          Rondônia  Masculino     48  Branca  15 anos ou mais
# 1        2012          Rondônia   Feminino     48  Branca  15 anos ou mais
# 2        2012          Rondônia   Feminino     23  Branca  15 anos ou mais
# 3        2012          Rondônia   Feminino     21  Branca          14 anos
# 4        2012          Rondônia   Feminino     54  Branca  15 anos ou mais
# ...       ...               ...        ...    ...     ...              ...
# 362446   2012  Distrito Federal   Feminino     51  Branca  15 anos ou mais
# 362447   2012  Distrito Federal  Masculino     53  Branca          12 anos
# 362448   2012  Distrito Federal  Masculino     21  Branca          13 anos
# 362449   2012  Distrito Federal  Masculino     19  Branca          13 anos
# 362450   2012  Distrito Federal  Masculino     40  Branca  15 anos ou mais
#
#         V4729
# 0         232
# 1         232
# 2         232
# 3         232
# 4         232
# ...       ...
# 362446    290
# 362447    290
# 362448    290
# 362449    290
# 362450    290
#
# [362451 rows x 7 columns]

# %%
df.dropna()  # remove linhas com ao menos um valor inválido - mas não altera o dataframe original repare que a linha 4 com dados NAN foi eliminada, mas TODA A LINHA,atentar aos dados
# Out:
#         V0101                UF      V0302  V8005   V0404            V4803  \
# 0        2012          Rondônia  Masculino     48  Branca  15 anos ou mais
# 1        2012          Rondônia   Feminino     48  Branca  15 anos ou mais
# 2        2012          Rondônia   Feminino     23  Branca  15 anos ou mais
# 3        2012          Rondônia   Feminino     21  Branca          14 anos
# 5        2012          Rondônia  Masculino     56   Preta  15 anos ou mais
# ...       ...               ...        ...    ...     ...              ...
# 362441   2012  Distrito Federal  Masculino     49  Branca          11 anos
# 362442   2012  Distrito Federal   Feminino     47  Branca          11 anos
# 362443   2012  Distrito Federal  Masculino     22   Parda  15 anos ou mais
# 362447   2012  Distrito Federal  Masculino     53  Branca          12 anos
# 362450   2012  Distrito Federal  Masculino     40  Branca  15 anos ou mais
#
#         V4718  V4720  V4729
# 0        3000   3000    232
# 1        3000   3000    232
# 2        1100   1100    232
# 3        1100   1100    232
# 5       10000  10000    232
# ...       ...    ...    ...
# 362441   3000   3000    290
# 362442   3000   3000    290
# 362443   1400   1400    290
# 362447  20000  20000    290
# 362450  13000  13000    290
#
# [173539 rows x 9 columns]

# %%
ndf = df.dropna()  # criando um NOVO dataframe com as linhas inválidas removidas, criado novo data frame sem a linha com problema

# %%
ndf.head()  #  exibe as primeiras linhas da tabela
# Out:
#    V0101        UF      V0302  V8005   V0404            V4803  V4718  V4720  \
# 0   2012  Rondônia  Masculino     48  Branca  15 anos ou mais   3000   3000
# 1   2012  Rondônia   Feminino     48  Branca  15 anos ou mais   3000   3000
# 2   2012  Rondônia   Feminino     23  Branca  15 anos ou mais   1100   1100
# 3   2012  Rondônia   Feminino     21  Branca          14 anos   1100   1100
# 5   2012  Rondônia  Masculino     56   Preta  15 anos ou mais  10000  10000
#
#    V4729
# 0    232
# 1    232
# 2    232
# 3    232
# 5    232

# %%
ndf.dtypes  # informa os tipos de dados de cada coluna
# nacoluna 4718 e 4720 os valores estao como objct mas deveriam estar como float
# Out:
# V0101     int64
# UF       object
# V0302    object
# V8005     int64
# V0404    object
# V4803    object
# V4718    object
# V4720    object
# V4729     int64
# dtype: object

# %%
df["V4718"] = pd.to_numeric(df["V4718"],errors="coerce")  # transformar dados da coluna em float e substituir os erros por NaN
df["V4720"] = pd.to_numeric(df["V4720"],errors="coerce")

# %%
df.dtypes  # informa os tipos de dados de cada coluna
# Out:
# V0101      int64
# UF        object
# V0302     object
# V8005      int64
# V0404     object
# V4803     object
# V4718    float64
# V4720    float64
# V4729      int64
# dtype: object

# %% [markdown]
# Variaveis Qualitativas e Quantitativas

# %%
df.select_dtypes(include=['object'])  # seleciona os valores qualitativos encontrados nos dados
# Out:
#                       UF      V0302   V0404            V4803
# 0               Rondônia  Masculino  Branca  15 anos ou mais
# 1               Rondônia   Feminino  Branca  15 anos ou mais
# 2               Rondônia   Feminino  Branca  15 anos ou mais
# 3               Rondônia   Feminino  Branca          14 anos
# 4               Rondônia   Feminino  Branca  15 anos ou mais
# ...                  ...        ...     ...              ...
# 362446  Distrito Federal   Feminino  Branca  15 anos ou mais
# 362447  Distrito Federal  Masculino  Branca          12 anos
# 362448  Distrito Federal  Masculino  Branca          13 anos
# 362449  Distrito Federal  Masculino  Branca          13 anos
# 362450  Distrito Federal  Masculino  Branca  15 anos ou mais
#
# [362451 rows x 4 columns]

# %%
df.select_dtypes(include=['number'])  # seleciona os valores quantitativos encontrados nos dados
# Out:
#         V0101  V8005    V4718    V4720  V4729
# 0        2012     48   3000.0   3000.0    232
# 1        2012     48   3000.0   3000.0    232
# 2        2012     23   1100.0   1100.0    232
# 3        2012     21   1100.0   1100.0    232
# 4        2012     54      NaN    460.0    232
# ...       ...    ...      ...      ...    ...
# 362446   2012     51      NaN      0.0    290
# 362447   2012     53  20000.0  20000.0    290
# 362448   2012     21      NaN      0.0    290
# 362449   2012     19      NaN      0.0    290
# 362450   2012     40  13000.0  13000.0    290
#
# [362451 rows x 5 columns]

# %% [markdown]
# Discretos e Contínuos

# %%
print(type(df.V0101[1]))  # valor quantitativo discreto (finito) da coluna e posição indicada
df.V0101[132] # ver a linha 132 da coluna V0101
# Out:
# <class 'numpy.int64'>
# 2012

# %%
pdmedia = ndf.V8005.mean()   # valor quantitativo contínuo (não enumerável) - média das idades pela PANDAS
print("A média é: ", pdmedia)
type(pdmedia)  # tipo da variável calculada
# Out:
# A média é:  37.964059951941636
# numpy.float64

# %%
npmedia = np.mean(ndf.V8005)   # valor quantitativo contínuo (não enumerável) - média das idades pela NUMPY
print("A média é: ",npmedia)
# sempre tratar a base e tirar as , para . para que seja possível tratar no python
# Out:
# A média é:  37.964059951941636

# %% [markdown]
# Representação numérica

# %%
print("%.2f" % pdmedia)   # arredondamento 2 casas decimais
# Out:
# 37.96

# %%
print("%.5f" % pdmedia)   # arredondamento 5 casas decimais
# Out:
# 37.96406

# %%
print('{:e}'.format(pdmedia))   # notação científica
# Out:
# 3.796406e+01

# %%
print('{:.2e}'.format(pdmedia))   # notação científica com 2 casas decimais
# Out:
# 3.80e+01

# %% [markdown]
# Frequencia Absoluta

# %%
ndf.V0404.value_counts()   #  frequência qualitativa - características físicas
# Out:
# Parda       80133
# Branca      76141
# Preta       15794
# Amarela       789
# Indígena      682
# Name: V0404, dtype: int64

# %%
ndf.V8005.value_counts()    # frequência quantitativa - idade
# Out:
# 30     5132
# 32     4857
# 33     4660
# 31     4574
# 27     4513
#        ...
# 102       1
# 96        1
# 99        1
# 95        1
# 117       1
# Name: V8005, Length: 90, dtype: int64

# %% [markdown]
# Frequencia Relativa

# %%
print("número total de observações: ", len(ndf.V0404) )   #  número total de observações - linhas

np.divide(ndf.V0404.value_counts(), len(ndf.V0404))  #  frequência relativa da coluna indicada - características físicas
# Out:
# número total de observações:  173539
# Parda       0.461758
# Branca      0.438754
# Preta       0.091011
# Amarela     0.004547
# Indígena    0.003930
# Name: V0404, dtype: float64

# %%
print("número total de observações: ", len(ndf.V8005))   #  número total de observações - linhas

np.divide(ndf.V8005.value_counts() , len(ndf.V8005))  #  frequência relativa da coluna indicada - idade
# Out:
# número total de observações:  173539
# 30     0.029573
# 32     0.027988
# 33     0.026853
# 31     0.026357
# 27     0.026006
#          ...
# 102    0.000006
# 96     0.000006
# 99     0.000006
# 95     0.000006
# 117    0.000006
# Name: V8005, Length: 90, dtype: float64
